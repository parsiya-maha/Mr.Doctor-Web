# %%
import os
import numpy as np
import shutil

# %%
DATASET_PATH = r"D:\dataset"
os.chdir(DATASET_PATH)
os.getcwd()
# Out:
# 'D:\\dataset'

# %%
os.listdir("Training")
# Out:
# ['BrainTumors', 'BreastCancer', 'CervicalCancer', 'KidneyStone', 'LungCancer']

# %%
for cancer_path in os.listdir("Training") :
    cor_cancer_path = os.path.join("Training",cancer_path)

    for _class in os.listdir(cor_cancer_path) :
        for image in os.listdir(os.path.join(cor_cancer_path,_class)) :
            image_path = os.path.join(cor_cancer_path,_class,image)

            shutil.move(image_path,cor_cancer_path)
            print(image_path)
# Out:
# Training\LungCancer\colon_aca\colon_aca_0001.jpg
# Training\LungCancer\colon_aca\colon_aca_0002.jpg
# Training\LungCancer\colon_aca\colon_aca_0003.jpg
# Training\LungCancer\colon_aca\colon_aca_0004.jpg
# Training\LungCancer\colon_aca\colon_aca_0005.jpg
# Training\LungCancer\colon_aca\colon_aca_0006.jpg
# Training\LungCancer\colon_aca\colon_aca_0007.jpg
# Training\LungCancer\colon_aca\colon_aca_0008.jpg
# Training\LungCancer\colon_aca\colon_aca_0009.jpg
# Training\LungCancer\colon_aca\colon_aca_0010.jpg
# Training\LungCancer\colon_aca\colon_aca_0011.jpg
# Training\LungCancer\colon_aca\colon_aca_0012.jpg
# Training\LungCancer\colon_aca\colon_aca_0013.jpg
# Training\LungCancer\colon_aca\colon_aca_0014.jpg
# Training\LungCancer\colon_aca\colon_aca_0015.jpg
# Training\LungCancer\colon_aca\colon_aca_0016.jpg
# Training\LungCancer\colon_aca\colon_aca_0017.jpg
# Training\LungCancer\colon_aca\colon_aca_0018.jpg
# Training\LungCancer\colon_aca\colon_aca_0019.jpg
# ...
